# %%
# %sql
select count(*) from wine.winequality_red

# %%
df = spark.sql('select * from wine.winequality_red')

# %%
display(df)

# %%
df.count()

# %%
display(df.describe())

# %%
display(df.select('pH'))

# %%
display(df.groupBy('alcohol').count().orderBy("alcohol"))

# %%
from pyspark.sql.functions import col
display(df.select('alcohol','fixed acidity').filter(df['fixed acidity'] > 7.5  ))

# %%
from pyspark.sql.functions import stddev, col
display(df.select(stddev(col('density')).alias('stddev_density')))
